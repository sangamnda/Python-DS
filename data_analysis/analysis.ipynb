# %%
import pandas as pd

# %% [markdown]
# - Creating dataset
#     - dictionary of item
#     - list of items
#     - import csv, excel and json files
# - read the data
# - selection of data
# - cleanin of data
# - visualizing the data
# - saving the data

# %%
movies = {
    'titl' : ['DDLJ', 'RRR', 'PK', 'KGF', 'YJHD'],
    'ratings' : [4.5, 5.0, 3.5, 4.0, 4.5],
    'year' : [2021, 2000, 2022, 2020, 2020]
    }
pd.DataFrame(movies)
# Out:
#    titl  ratings  year
# 0  DDLJ      4.5  2021
# 1   RRR      5.0  2000
# 2    PK      3.5  2022
# 3   KGF      4.0  2020
# 4  YJHD      4.5  2020

# %%
films = [
    {'title' : 'RRR', 'ratings': 4.5, 'year': 2021},
    {'title': 'DDLJ', 'ratings': 5.0, 'year': 2000},
    {'title': 'PK', 'ratings': 3.5, 'year': 2022},
    {'title': 'KGF', 'ratings': 4.0, 'year': 2020}
]
pd.DataFrame(films)
# Out:
#   title  ratings  year
# 0   RRR      4.5  2021
# 1  DDLJ      5.0  2000
# 2    PK      3.5  2022
# 3   KGF      4.0  2020

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# - Get Basic Insight of Dataset

# %%
df.head() # gives top 5 rows by default, if we pass the arguments in parentheses we=ill get the same number
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(20)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
df.tail() # gives top 5 bottom by default, if we pass the arguments in parentheses we=ill get the same number
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.tail(18) # gives top 5 bottom by default, if we pass the arguments in parentheses we=ill get the same number
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21595  1972201967  20141031T000000   520000.0         2       2.25
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21597   191100405  20150421T000000  1575000.0         4       3.25
# 21598  8956200760  20141013T000000   541800.0         4       2.50
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21601  5100403806  20150407T000000   467000.0         3       2.50
# 21602   844000965  20140626T000000   224000.0         3       1.75
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.sample() # gives one random row from the dataset by default
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 1055  5416300240  20150202T000000  935000.0         4        4.5         5670
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1055     84267     2.0           0     2  ...     11        5670
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 1055              0      2008             0    98010  47.323 -122.044
#
#       sqft_living15  sqft_lot15
# 1055           4100       83729
#
# [1 rows x 21 columns]

# %%
df.sample(6)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 19958  5015001452  20150414T000000  950000.0         3       2.50
# 15407   104560280  20140522T000000  273000.0         4       3.00
# 15374  7148700050  20150126T000000  340000.0         3       1.75
# 17671  8078430360  20141216T000000  505000.0         3       2.50
# 18099  3395800455  20140625T000000  150000.0         2       1.00
# 8994   7893203480  20150512T000000  205000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 19958         2280      2296     3.0           0     0  ...      9
# 15407         1990      6180     2.0           0     0  ...      7
# 15374         2650      7378     1.0           0     0  ...      7
# 17671         1820     11012     2.0           0     0  ...      8
# 18099          890      8100     1.0           0     0  ...      6
# 8994          1420      5000     1.0           0     0  ...      7
#
# ...

# %%
df.info() # gives info about data in concise form
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum() # to check null values in the data and sum their count
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe() # gives statistics of all the columns
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# - Data selection

# %% [markdown]
# - Data selection
#     - Row wise selection
#         - iloc - index based selection
#         - loc - label based selection
#     - Column wise selection
#         - dictionary like selection
#         - object like selection

# %%
df.iloc[4]
# Out:
# id                    1954400510
# date             20150218T000000
# price                   510000.0
# bedrooms                       3
# bathrooms                    2.0
# sqft_living                 1680
# sqft_lot                    8080
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 4, dtype: object

# %%
df.loc[15]
# Out:
# id                    9297300055
# date             20150124T000000
# price                   650000.0
# bedrooms                       4
# bathrooms                    3.0
# sqft_living                 2950
# sqft_lot                    5000
# floors                       2.0
# waterfront                     0
# view                           3
# condition                      3
# grade                          9
# sqft_above                  1980
# sqft_basement                970
# yr_built                    1979
# yr_renovated                   0
# zipcode                    98126
# lat                      47.5714
# long                    -122.375
# sqft_living15               2140
# sqft_lot15                  4000
# Name: 15, dtype: object

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.iloc[[4,8,25]] # indexing with perticuler data
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 4   1954400510  20150218T000000  510000.0         3        2.0         1680
# 8   2414600126  20150415T000000  229500.0         3        1.0         1780
# 25  1202000200  20141103T000000  233000.0         3        2.0         1710
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 4       8080     1.0           0     0  ...      8        1680              0
# 8       7470     1.0           0     0  ...      7        1050            730
# 25      4697     1.5           0     0  ...      6        1710              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 4       1987             0    98074  47.6168 -122.045           1800
# 8       1960             0    98146  47.5123 -122.337           1780
# 25      1941             0    98002  47.3048 -122.218           1030
#
#     sqft_lot15
# 4         7503
# 8         8113
# 25        4705
# ...

# %%
df.iloc[[3,6,12,76], [1,4,6,7]] # indexing with perticular columns and rows
# Out:
#                date  bathrooms  sqft_lot  floors
# 3   20141209T000000       3.00      5000     1.0
# 6   20140627T000000       2.25      6819     2.0
# 12  20140528T000000       1.00     19901     1.5
# 76  20141013T000000       1.75      7300     1.0

# %%
df.iloc[34:56] # slicing with dataset
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 34  7955080270  20141203T000000   322500.0         4       2.75         2060
# 35  9547205180  20140613T000000   696000.0         3       2.50         2300
# 36  9435300030  20140528T000000   550000.0         4       1.00         1660
# 37  2768000400  20141230T000000   640000.0         4       2.00         2360
# 38  7895500070  20150213T000000   240000.0         4       1.00         1220
# 39  2078500320  20140620T000000   605000.0         4       2.50         2620
# 40  5547700270  20140715T000000   625000.0         4       2.50         2570
# 41  7766200013  20140811T000000   775000.0         4       2.25         4220
# 42  7203220400  20140707T000000   861990.0         5       2.75         3595
# 43  9270200160  20141028T000000   685000.0         3       1.00         1570
# 44  1432701230  20140729T000000   309000.0         3       1.00         1280
# ...

# %%
df = df.set_index('id') # to find a speciific data from dataset but the condition is index column should be unique
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[6414100192] # print with unique id number or unique data
# Out:
# date             20141209T000000
# price                   538000.0
# bedrooms                       3
# bathrooms                   2.25
# sqft_living                 2570
# sqft_lot                    7242
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  2170
# sqft_basement                400
# yr_built                    1951
# yr_renovated                1991
# zipcode                    98125
# lat                       47.721
# long                    -122.319
# sqft_living15               1690
# sqft_lot15                  7639
# Name: 6414100192, dtype: object

# %% [markdown]
# - Single column selection
#     - dictionary like selection
#     - object like selection
# - Multiple coulmns selction
#     - dictinary like selection

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.loc[2487200875]['price']
# Out:
# np.float64(604000.0)

# %%
df.loc[2487200875, 'price']
# Out:
# np.float64(604000.0)

# %%
df[['price', 'floors', 'bathrooms', 'bedrooms']]
# Out:
#                price  floors  bathrooms  bedrooms
# id
# 7129300520  221900.0     1.0       1.00         3
# 6414100192  538000.0     2.0       2.25         3
# 5631500400  180000.0     1.0       1.00         2
# 2487200875  604000.0     1.0       3.00         4
# 1954400510  510000.0     1.0       2.00         3
# ...              ...     ...        ...       ...
# 263000018   360000.0     3.0       2.50         3
# 6600060120  400000.0     2.0       2.50         4
# 1523300141  402101.0     2.0       0.75         2
# 291310100   400000.0     2.0       2.50         3
# 1523300157  325000.0     2.0       0.75         2
#
# [21613 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop = ['sqft_living15', 'sqft_lot15']
df = df.drop(columns = cols_to_drop)
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.drop(labels = [2487200875])
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.drop(labels = [6414100192], inplace = True)

# %%
df.head()
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3        1.0         1180
# 5631500400  20150225T000000   180000.0         2        1.0          770
# 2487200875  20141209T000000   604000.0         4        3.0         1960
# 1954400510  20150218T000000   510000.0         3        2.0         1680
# 7237550310  20140512T000000  1225000.0         4        4.5         5420
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
# 7237550310    101930     1.0           0     0          3     11        3890
#
# ...

# %%
name_update = {
    'lat': 'latitude',
    'long':'longitude'
}
df.rename(columns=name_update, inplace = True)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
df.tail()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 263000018       1131     3.0           0     0          3      8        1530
# 6600060120      5813     2.0           0     0          3      8        2310
# 1523300141      1350     2.0           0     0          3      7        1020
# 291310100       2388     2.0           0     0          3      8        1600
# 1523300157      1076     2.0           0     0          3      7        1020
#
# ...

# %%
df.head(12)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# 2008000270  20150115T000000   291850.0         3       1.50         1060
# 2414600126  20150415T000000   229500.0         3       1.00         1780
# 3793500160  20150312T000000   323000.0         3       2.50         1890
# 1736800520  20150403T000000   662500.0         3       2.50         3560
# 9212900260  20140527T000000   468000.0         2       1.00         1160
# 114101516   20140528T000000   310000.0         3       1.00         1430
#
# ...

# %% [markdown]
# ### Manupulating and cleaning data
#
# - removing rows and columns
# - rename column names
# - adding columns
# - changing datatypes of data
# - handling missing values
# - dropping missing values
# - using apply () method

# %%
df.yr_built.astype('float64')
# Out:
# id
# 7129300520    1955.0
# 5631500400    1933.0
# 2487200875    1965.0
# 1954400510    1987.0
# 7237550310    2001.0
#                ...
# 263000018     2009.0
# 6600060120    2014.0
# 1523300141    2009.0
# 291310100     2004.0
# 1523300157    2008.0
# Name: yr_built, Length: 21612, dtype: float64

# %%
df
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...
