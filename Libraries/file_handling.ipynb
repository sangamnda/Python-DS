# %% [markdown]
# ## OS library for handling

# %%
import os

# %%
print("current working directory is: ", os.getcwd())
# Out:
# current working directory is:  c:\Users\sssul\OneDrive\Documents\Python DS\Libraries

# %%
files = os.listdir()
print("files in current working directory: ", files)
# Out:
# files in current working directory:  ['file_handling.ipynb', 'Library.ipynb']

# %%
files = os.listdir(r"D:\JHT QP\Hindi translation\PGDT 05")
print("files in current working directory: ", files)
print(len(files))
# Out:
# files in current working directory:  ['Anuvaad-Pariyojana.pdf']
# 1

# %%
files = os.listdir(r"C:\Users\sssul\OneDrive\Documents\Python DS")
print("files in current working directory: ", files)
print(len(files))
# Out:
# files in current working directory:  ['.git', 'basics.ipynb', 'Conditions', 'data_structure', 'Data_types', 'Functions', 'Libraries', 'Loops', 'oprators']
# 9

# %%
total_files = 0
for path, folders, files in os.walk(r"C:\Users\sssul\OneDrive\Documents\Python DS"):
    print("=>", path)
    print("📁", folders)
    print("🗄️", files)
    total_files += len(files)
print("total files in directory tree: ", total_files)
# Out:
# => C:\Users\sssul\OneDrive\Documents\Python DS
# 📁 ['.git', 'Conditions', 'data_structure', 'Data_types', 'Functions', 'Libraries', 'Loops', 'oprators']
# 🗄️ ['basics.ipynb']
# => C:\Users\sssul\OneDrive\Documents\Python DS\.git
# 📁 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗄️ ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# => C:\Users\sssul\OneDrive\Documents\Python DS\.git\hooks
# 📁 []
# 🗄️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# => C:\Users\sssul\OneDrive\Documents\Python DS\.git\info
# 📁 []
# 🗄️ ['exclude']
# => C:\Users\sssul\OneDrive\Documents\Python DS\.git\logs
# 📁 ['refs']
# 🗄️ ['HEAD']
# => C:\Users\sssul\OneDrive\Documents\Python DS\.git\logs\refs
# ...

# %%
files = r"D:\Softwares\QHTSFT32.EXE"
if os.path.exists(files):
    print("The file exist")
else:
    print("The files does not exist")
# Out:
# The file exist
